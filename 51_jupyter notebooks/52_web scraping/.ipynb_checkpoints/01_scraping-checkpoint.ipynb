# %% [markdown]
# <参照URL>
#
# https://www.sejuku.net/blog/51241
#
# <前提知識>
#
# ・「Requests」はHTTPライブラリでWebページを取得するためのもの
#
# ・「Selenium」はブラウザ操作をするためのもの
#
# ・「Beautiful Soup」は取得したHTMLから情報を抽出するためのもの

# %% [markdown]
# ------------[Reqests] の基本的な操作------------

# %%
import requests

r = requests.get('https://news.yahoo.co.jp')  #get関数を用いてURLを指定→情報を格納する

# %%
print(r.headers)  #headers = webサイトの「header」情報を取得
print("--------")
print(r.encoding) #encoding = webサイトの「文字コード」情報を取得
#print(r.content)   #content = webサイトの「bode」以下の情報を取得
# Out:
# {'Cache-Control': 'private, no-cache, no-store, must-revalidate', 'Content-Encoding': 'gzip', 'Content-Type': 'text/html;charset=UTF-8', 'Date': 'Fri, 12 Jun 2020 02:43:38 GMT', 'Set-Cookie': 'B=f9h42htfe5qup&b=3&s=f2; expires=Mon, 13-Jun-2022 02:43:38 GMT; path=/; domain=.yahoo.co.jp, XB=f9h42htfe5qup&b=3&s=f2; expires=Mon, 13-Jun-2022 02:43:38 GMT; path=/; domain=.yahoo.co.jp; secure; samesite=none', 'Vary': 'Accept-Encoding', 'X-Content-Type-Options': 'nosniff', 'X-Download-Options': 'noopen', 'X-Frame-Options': 'DENY', 'X-Vcap-Request-Id': 'daf97c34-7035-41c6-5008-76d332659919', 'X-Xss-Protection': '1; mode=block', 'Age': '2', 'Server': 'ATS', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Via': 'http/1.1 edge1835.img.bbt.yahoo.co.jp (ApacheTrafficServer [c sSf ])'}
# --------
# UTF-8

# %% [markdown]
# ------------[Beautiful Soup] の活用------------

# %%
from bs4 import BeautifulSoup
 
html = "<h1>sayhello</h1>,<h1>saysay</h1>,<h2>say</h2>"
 
soup = BeautifulSoup(html, "html.parser")  #第一引数：解析したいもの、第二引数：パーサ
 
print(soup.select("h1"))
# Out:
# [<h1>sayhello</h1>, <h1>saysay</h1>]

# %% [markdown]
# ------------[Beautiful Soup / Reqests] の活用------------

# %%
import requests
from bs4 import BeautifulSoup
 
r = requests.get("https://news.yahoo.co.jp/")
 
soup = BeautifulSoup(r.content, "html.parser")
 
# ニュース一覧を抽出
print(soup.find("ul", "newsFeed_list"))
# Out:
# <ul class="newsFeed_list"><li class="newsFeed_item" data-ual="content_id:dd13fdf4223f3c2cdc65eec88f725fe388ada7be;id_type:shannon_article;screen_id:list-all;opttype:pc;service:news;apptype:web;sec:st_maj;slk:title;pos:1;" data-ual-view-type="list"><a class="newsFeed_item_link" data-ual-gotocontent="true" data-ylk="rsec:st_maj;slk:title;pos:1;" href="https://headlines.yahoo.co.jp/hl?a=20200612-00010005-abema-ent"><div class="newsFeed_item_thumbnail"><div class="sc-jAaTju gpQmdr thumbnail thumbnail-middle"><picture><source srcset="https://news-pctr.c.yimg.jp/q3eRX5yhdvIzm3wm4v0_ThBVA3pQLQwQ1vxac1jmZb9QfidB2-PPDAgv3WwEbq8zN8Svs_Q0v4uZBkqHr-r0Kz-iO-gQCy2j_hAzGl5S4cD076WdLrJ8iiMM3c9iLCq9" type="image/webp"/><source srcset="https://news-pctr.c.yimg.jp/q3eRX5yhdvIzm3wm4v0_ThBVA3pQLQwQ1vxac1jmZb9QfidB2-PPDAgv3WwEbq8zeoWbNytcVCpFSF0Dxk1j5-IY4GQYpE3xDnndFh-a1vFGWvkLiAuvaCvP7G_dzmtm" type="image/jpeg"/><img alt="" class="sc-jDwBTQ jhlPYu" src="https://news-pctr.c.yimg.jp/q3eRX5yhdvIzm3wm4v0_ThBVA3pQLQwQ1vxac1jmZb9QfidB2-PPDAgv3WwEbq8zeoWbNytcVCpFSF0Dxk1j5-IY4GQYpE3xDnndFh-a1vFGWvkLiAuvaCvP7G_dzmtm"/></picture></div></div><div class="newsFeed_item_text"><div class="newsFeed_item_title">長谷川京子、オフ感溢れるキャミソール姿を披露 「美しすぎ」「色気最強だわ…」の声</div><div class="newsFeed_item_sub"><div class="newsFeed_item_sourceWrap"><span class="newsFeed_item_media">ABEMA TIMES</span></div></div></div></a></li><li class="newsFeed_item" data-ual="content_id:82d65f99a9bbf95246527e3b742a48be859fcb4f;id_type:shannon_article;screen_id:list-all;opttype:pc;service:news;apptype:web;sec:st_maj;slk:title;pos:2;" data-ual-view-type="list"><a class="newsFeed_item_link" data-ual-gotocontent="true" data-ylk="rsec:st_maj;slk:title;pos:2;" href="https://headlines.yahoo.co.jp/hl?a=20200612-00149317-etalent-musi"><style data-styled="bHzYmW gpQmdr hICjPD hggbiO fnSmkg" data-styled-streamed="true" data-styled-version="4.4.1">
# /* sc-component-id: sc-jAaTju */
# .bHzYmW{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;overflow:hidden;position:relative;background-color:#000;height:80px;width:80px;} .bHzYmW::after{content:'';display:block;position:absolute;top:0;left:0;box-sizing:border-box;width:100%;height:100%;border:solid 1px rgba(0,0,0,0.06);}.gpQmdr{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;overflow:hidden;position:relative;background-color:#efefef;height:80px;width:80px;} .gpQmdr::after{content:'';display:block;position:absolute;top:0;left:0;box-sizing:border-box;width:100%;height:100%;border:solid 1px rgba(0,0,0,0.06);}
# /* sc-component-id: sc-gPEVay */
# .hICjPD{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;position:absolute;right:0;bottom:0;padding:calc(4px / 2) 4px;color:#fff;font-family:Helvetica;font-size:11px;line-height:1;background-color:rgba(0,0,0,0.7);} .hICjPD::before{padding-right:2px;vertical-align:middle;} .hICjPD:empty{min-width:calc(11px + 4px * 2);min-height:calc(11px + 4px * 2);} .hICjPD:empty::before{position:absolute;top:50%;left:50%;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);padding:0;}
# /* sc-component-id: sc-jlyJG */
# .hggbiO{margin:0 -2px 0 -2px;}
# /* sc-component-id: sc-iRbamj */
# .fnSmkg{margin-left:4px;}</style><div class="newsFeed_item_thumbnail"><div class="sc-jAaTju gpQmdr thumbnail thumbnail-middle"><picture><source srcset="https://news-pctr.c.yimg.jp/q3eRX5yhdvIzm3wm4v0_Tl9Dcoy2ZVnjJavNFhTeemjAQ0IzAX7BZkkgqrXPtW9eptiqYHwfAUg73ERSquGrDjulwCYjxo3zAuEn8PBXOO0oAp1PChOjzPWKsTOL2giIk1aOZMIw3DuuQIgu5XTT6gv691hEKuCbtikgsCriCSpsYwXms-lyaaP8E6nnT0aw" type="image/webp"/><source srcset="https://news-pctr.c.yimg.jp/q3eRX5yhdvIzm3wm4v0_Tl9Dcoy2ZVnjJavNFhTeemjAQ0IzAX7BZkkgqrXPtW9eptiqYHwfAUg73ERSquGrDjulwCYjxo3zAuEn8PBXOO2qWal34qWv3Xv_znoxM-WxWjxbYwx97VuA86xT6e7fzs24AOXrfuT7WiNafYN61RkYFN3rWrgB7hSP3poVI6vo" type="image/jpeg"/><img alt="" class="sc-jDwBTQ jhlPYu" src="https://news-pctr.c.yimg.jp/q3eRX5yhdvIzm3wm4v0
https://news-pctr.c.yimg.jp/q3eRX5yhdvIzm3wm4v0_TrwtPfo8Hky_Bg_Fa1uUu6-MJk8KEXoFfKFEoAtqw8zxvzYcl9QuVV2Va0TTvC2zrpRkrt7SEUhOhbMVva548cthXIxDYejYnPAUsSMnLwLNmHTTowzwzAROwxz-zIOvKzAOr22xosqSBijwDFfMvzcJi3QyhHdlwHx1yo9HFEAx"/></picture></div></div><div class="newsFeed_item_text"><div class="newsFeed_item_title">渡部との不倫否定の女性、中傷やまず…このままなら「法的処置の準備します」</div><div class="newsFeed_item_sub"><div class="newsFeed_item_sourceWrap"><span class="newsFeed_item_media">デイリースポーツ</span></div></div></div></a></li><li class="newsFeed_item"><div id="ad29"></div></li><li class="newsFeed_item" data-ual="content_id:d72a552f1837ced600fb08f9e1d1190317941458;id_type:shannon_article;screen_id:list-all;opttype:pc;service:news;apptype:web;sec:st_maj;slk:title;pos:31;" data-ual-view-type="list"><a class="newsFeed_item_link" data-ual-gotocontent="true" data-ylk="rsec:st_maj;slk:title;pos:31;" href="https://headlines.yahoo.co.jp/hl?a=20200612-00000002-kumanichi-l43"><div class="newsFeed_item_thumbnail"><div class="sc-jAaTju gpQmdr thumbnail thumbnail-middle"><picture><source srcset="https://news-pctr.c.yimg.jp/q3eRX5yhdvIzm3wm4v0_TrwtPfo8Hky_Bg_Fa1uUu6-jeAGb3yHnVjxXkSCsBZ0unAF7nUjmMsMt6Mhf2OnXpTw4RhywGbtzFXBg1QPWQJF5FyD8DvSxbbc8hP8k018y" type="image/webp"/><source srcset="https://news-pctr.c.yimg.jp/q3eRX5yhdvIzm3wm4v0_TrwtPfo8Hky_Bg_Fa1uUu6-jeAGb3yHnVjxXkSCsBZ0unAF7nUjmMsMt6Mhf2OnXped-fnsAWqmyueqwy6LclulwD66fVSEQA1l_BP-a8DXV" type="image/jpeg"/><img alt="" class="sc-jDwBTQ jhlPYu" src="https://news-pctr.c.yimg.jp/q3eRX5yhdvIzm3wm4v0_TrwtPfo8Hky_Bg_Fa1uUu6-jeAGb3yHnVjxXkSCsBZ0unAF7nUjmMsMt6Mhf2OnXped-fnsAWqmyueqwy6LclulwD66fVSEQA1l_BP-a8DXV"/></picture></div></div><div class="newsFeed_item_text"><div class="newsFeed_item_title">【熊本県感染症情報】突発性発疹、４週連続増</div><div class="newsFeed_item_sub"><div class="newsFeed_item_sourceWrap"><span class="newsFeed_item_media">熊本日日新聞</span></div></div></div></a></li><li class="newsFeed_item" data-ual="content_id:557f721dd61927b8dde5b5ccdf51d440fe16077f;id_type:shannon_article;screen_id:list-all;opttype:pc;service:news;apptype:web;sec:st_maj;slk:title;pos:32;" data-ual-view-type="list"><a class="newsFeed_item_link" data-ual-gotocontent="true" data-ylk="rsec:st_maj;slk:title;pos:32;" href="https://headlines.yahoo.co.jp/hl?a=202 ...
# /* sc-component-id: sc-jAaTju */
# .cZegIZ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;overflow:hidden;position:relative;background-color:#000;height:60px;width:60px;} .cZegIZ::after{content:'';display:block;position:absolute;top:0;left:0;box-sizing:border-box;width:100%;height:100%;border:solid 1px rgba(0,0,0,0.06);}.gaTjBB{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;overflow:hidden;position:relative;background-color:#efefef;height:60px;width:60px;} .gaTjBB::after{content:'';display:block;position:absolute;top:0;left:0;box-sizing:border-box;width:100%;height:100%;border:solid 1px rgba(0,0,0,0.06);}</style><div class="newsFeed_item_sourceWrap"><span class="newsFeed_item_media">NEWS ポストセブン</span></div></div></div></a></li><li class="newsFeed_item"><div id="ad41"></div></li><li class="newsFeed_item" data-ual="content_id:78547504c8876f1c4cea68212fc611f651980bd0;id_type:shannon_article;screen_id:list-all;opttype:pc;service:news;apptype:web;sec:st_maj;slk:title;pos:43;" data-ual-view-type="list"><a class="newsFeed_item_link" data-ual-gotocontent="true" data-ylk="rsec:st_maj;slk:title;pos:43;" href="https://headlines.yahoo.co.jp/article?a=20200609-00000031-sasahi-ent"><div class="newsFeed_item_thumbnail"><div class="sc-jAaTju gpQmdr thumbnail thumbnail-middle"><picture><source srcset="https://news-pctr.c.yimg.jp/q3eRX5yhdvIzm3wm4v0_TstttrGRYj_oOJ1ireWJs-teO982PBxSqgoSpDEdlQb7bMEgxTiwVqQqexMshZIKf4IoiBHTzJTvD9nUOeE7mf_7TqIFXP7gIXyWAcvJ-Lz25Ppnzp7isAKUBguUal9wEXWvDqoz7MJTKEGimmuAxf9ufLJMlJ7yPbnYE0AWIsLw" type="image/webp"/><source srcset="https://news-pctr.c.yimg.jp/q3eRX5yhdvIzm3wm4v0_TstttrGRYj_oOJ1ireWJs-teO982PBxSqgoSpDEdlQb7bMEgxTiwVqQqexMshZIKf4IoiBHTzJTvD9nUOeE7mf8tjkS2bn1UY9g2ddqmw_-gSrbERv5KOmzVKKxMhOo47dUAHJbDJptRhYrmQfVIGSqOfM4ZcsuY_-Idrgidqs8g" type="image/jpeg"/><img alt="" class="sc-jDwBTQ jhlPYu" src="https://news-pctr.c.yimg.jp/q3eRX5yhdvIzm3wm4v0_TstttrGRYj_oOJ1ireWJs-teO982PBxSqgoSpDEdlQb7bMEgxTiwVqQqexMshZIKf4IoiBHTzJTvD9nUOeE7mf8tjkS2bn1UY9g2ddqmw_-gSrbERv5KOmzVKKxMhOo47dUAHJbDJptRhYrmQfVIGSqOfM4ZcsuY_-Idrgidqs8g"/></picture></div></div><div class="newsFeed_item_text"><div class="newsFeed_item_title">湘南乃風SHOCK EYEさん流「子の叱り方」　“子育てのいいとこ取り”はもう卒業！〈AERA〉</div><div class="newsFeed_item_sub"><div class="newsFeed_item_sourceWrap"><span class="newsFeed_item_media">AERA dot.</span></div></div></div></a></li><li class="newsFeed_item" data-ual="content_id:10aaab528c9db95eb2a0b8871af52af0a2b744ab;id_type:shannon_article;screen_id:list-all;opttype:pc;service:news;apptype:web;sec:st_maj;slk:title;pos:44;" data-ual-view-type="list"><a class="newsFeed_item_link" data-ual-gotocontent="true" data-ylk="rsec:st_maj;slk:title;pos:44;" href="https://headlines.yahoo.co.jp/hl?a=20200612-00000113-spnannex-ent"><div class="newsFeed_item_thumbnail"><div class="sc-jAaTju gpQmdr thumbnail thumbnail-middle"><picture><source srcset="https://news-pctr.c.yimg.jp/q3eRX5yhdvIzm3wm4v0_TrwtPfo8Hky_Bg_Fa1uUu6-EFpiI20SNIJvjnd_s4CDryLD-j585f9SXnwGbqitzkQqyPOTx9h4hwB82eKDAJa-6suIJNcObm2PDbpGPx20a" type="image/webp"/><source srcset="https://news-pctr.c.yimg.jp/q3eRX5yhdvIzm3wm4v0_TrwtPfo8Hky_Bg_Fa1uUu6-EFpiI20SNIJvjnd_s4CDryLD-j585f9SXnwGbqitzkazTrDIgsEOm-8dSdTPGu50ANTK1vlDB4R4eSk6sblff" type="image/jpeg"/><img alt="" class="sc-jDwBTQ jhlPYu" src="https://news-pctr.c.yimg.jp/q3eRX5yhdvIzm3wm4v0_TrwtPfo8Hky_Bg_Fa1uUu6-EFpiI20SNIJvjnd_s4CDryLD-j585f9SXnwGbqitzkazTrDIgsEOm-8dSdTPGu50ANTK1vlDB4R4eSk6sblff"/> ...

# %%
import requests
from bs4 import BeautifulSoup
	
r = requests.get("https://news.yahoo.co.jp/")
	
soup = BeautifulSoup(r.content, "html.parser")
	
#ニュース一覧のテキストのみ抽出
print(soup.find("ul", "newsFeed_list").text)
# Out:
# 長谷川京子、オフ感溢れるキャミソール姿を披露 「美しすぎ」「色気最強だわ…」の声ABEMA TIMES
# /* sc-component-id: sc-jAaTju */
# .bHzYmW{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;overflow:hidden;position:relative;background-color:#000;height:80px;width:80px;} .bHzYmW::after{content:'';display:block;position:absolute;top:0;left:0;box-sizing:border-box;width:100%;height:100%;border:solid 1px rgba(0,0,0,0.06);}.gpQmdr{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;overflow:hidden;position:relative;background-color:#efefef;height:80px;width:80px;} .gpQmdr::after{content:'';display:block;position:absolute;top:0;left:0;box-sizing:border-box;width:100%;height:100%;border:solid 1px rgba(0,0,0,0.06);}
# /* sc-component-id: sc-gPEVay */
# .hICjPD{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;position:absolute;right:0;bottom:0;padding:calc(4px / 2) 4px;color:#fff;font-family:Helvetica;font-size:11px;line-height:1;background-color:rgba(0,0,0,0.7);} .hICjPD::before{padding-right:2px;vertical-align:middle;} .hICjPD:empty{min-width:calc(11px + 4px * 2);min-height:calc(11px + 4px * 2);} .hICjPD:empty::before{position:absolute;top:50%;left:50%;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);padding:0;}
# /* sc-component-id: sc-jlyJG */
# .hggbiO{margin:0 -2px 0 -2px;}
# /* sc-component-id: sc-iRbamj */
# .fnSmkg{margin-left:4px;}「可愛いママ」浜崎あゆみ、“ミントグレー”ヘアのイメチェン＆オフショルワンピ姿を披露し反響「女子の憧れ」E-TALENTBANK小倉智昭、渡部の妻・佐々木希へ「気の毒でしょうがない」デイリースポーツ藤田ニコル　背中大胆露出の“猫ポーズ”写真公開に「大人の女になったねぇ～」スポニチアネックス玉川徹氏、小室圭さん法律専門誌への論文掲載を評価「バッシングする理由はどこにあるんだろう」スポーツ報知小林麻耶＆あきら。、芸術的マスク姿の夫婦ショットを公開「素敵な二人」「お洒落なペアルック」スポーツ報知アンミカ　石田純一の仕事復帰に「いい人っていうのと責任感がある行動っていうのは別」スポニチアネックス榮倉奈々　初めてのオーダーメイドシューズ披露に「かわいい」「オシャレ」「センス良さすぎ」スポニチアネックスおぎやはぎ「佐々木希さんには本当に申し訳ない」日刊スポーツ後藤真希の“大人ピンクコーデ“にファン「もう可愛い過ぎてブン殴りたい」「とにかく最高」ENCOUNT川口春奈　肩出しの大人っぽいショット披露に「最強美しい」「ため息しか出ない、美しさ」スポニチアネックス横山由依、ロングからショートに髪型一新「すっごい美人!!!」「夏らしくて素敵!」ENCOUNT新木優子の驚愕スタイルにファン唖然「顔葉っぱより小さくない?」　ノースリーブ私服が反響ENCOUNTウーマン村本　相方の「夜遊び」報道“お詫び”…２番組降ろされるも、世間無反応とデイリースポーツリモート出演で信用できるコメンテーターは？　3位山中教授、2位青木理、1位は？〈週刊朝日〉AERA dot.３０キロ減の日テレ安村アナ、加藤浩次も心配「健康は大事に…」デイリースポーツ0:44２６歳俳優、７０代女性へ強制わいせつ致傷日本テレビ系（NNN）イ・ボミの私服姿は「いつも可愛い！」　ワンピ＆メガネの“オシャレ黒コーデ”に反響THE ANSWER竹内涼真の元恋人・吉谷彩子の両親が告白「竹内君に言いたいこと」FRIDAY藤田ニコル、お気に入りのお酒は「梅酒ロック」　艶っぽい表情にファン悶絶「一緒に飲みたい」ENCOUNTアンジャ渡部建は複数女性と…美人妻と結婚した男ほど浮気する心理日刊ゲンダイDIGITALキャサリン妃　初公務から9年　高まり続ける英国内での称賛　「気遣いができて気さく」の声もHint-Pot霜降り明星、ニッポン放送にクレーム！？ 無関係のネットニュースに自身の写真が使われる原因か？ニッポン放送
# /* sc-component-id: sc-jAaTju */
# .gaTjBB{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;overflow:hidden;position:relative;background-color:#efefef;height:60px;width:60px;} .gaTjBB::after{content:'';display:block;position:absolute;top:0;left:0;box-sizing:border-box;width:100%;height:100%;border:solid 1px rgba(0,0,0,0.06);}
# /* sc-component-id: sc-jDwBTQ */
# .bymfKt{-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:middle;max-height:60px;max-width:60px;}ラサール石井を与党がマーク？ 炎上招いた反安倍発言「ひるおび！」起用に賛否東スポWeb渡部との不倫否定の女性、中傷やまず…このままなら「法的処置の準備します」デイリースポーツ【熊本県感染症情報】突発性発疹、４週連続増熊本日日新聞石田純一　約２カ月ぶり復帰　妻・理子に「お前のせいで肩身が狭い」と叱られたデイリースポーツ食べたら人に会えないほど強烈！？ ミニストップの「ポテトチップスにんにくパンチ」が衝撃的な旨さ食楽web違約金20億円の沢尻エリカが願う、年内“女優復帰”のシナリオFRIDAY“笑わない男”ラグビー稲垣、12年ミス日本グランプリ新井貴子と同棲スポニチアネックス霊的占い師・嶋田美幸さん「掃除を済ませればいいことが続く」女性自身眞子さまと小室圭さん、延期の“結婚宣言”は秋篠宮さま「立皇嗣の礼」後にデイリー新潮白T＆ジーンズ姿のイ・ダヒ、くるくるパーマがキュート朝鮮日報日本語版熊田曜子、ヒルズ多目的トイレは親子で頻繁利用「まさかそこで…気持ち悪くて」デイリースポーツ新型コロナ、重篤な後遺症の報告多数　一生苦しむ恐れも
# /* sc-component-id: sc-jAaTju */
# .cZegIZ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;overflow:hidden;position:relative;background-color:#000;height:60px;width:60px;} .cZegIZ::after{content:'';display:block;position:absolute;top:0;left:0;box-sizing:border-box;width:100%;height:100%;border:solid 1px rgba(0,0,0,0.06);}.gaTjBB{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;overflow:hidden;position:relative;background-color:#efefef;height:60px;width:60px;} .gaTjBB::after{content:'';display:block;position:absolute;top:0;left:0;box-sizing:border-box;width:100%;height:100%;border:solid 1px rgba(0,0,0,0.06);}NEWS ポストセブン湘南乃風SHOCK EYEさん流「子の叱り方」　“子育てのいいとこ取り”はもう卒業！〈AERA〉AERA dot.稲村亜美　ショートパンツの“見返り美人”ショット公開に「美脚ですねー」「足！なげぇ」スポニチアネックス「レイプドラッグ」で複数女性に乱暴か　福岡県警が容疑の40代男を逮捕西日本新聞大人の女性と少年の性愛は「レイプ」か「通過儀礼」か現代ビジネスキウイの兄弟に涙うるうる…話題のテレビCMが泣けるワケ大手小町（OTEKOMACHI）妊娠中の橋本マナミ、元気に動くお腹の動画公開「おぉー！元気な赤ちゃん」「神秘的…」オリコン玉川徹氏「東京アラート」解除の小池百合子都知事に「ロックダウン、ステイホ－ムにしても…なんとなく言いたいだけって感じ」スポーツ報知
